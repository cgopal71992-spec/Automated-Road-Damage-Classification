# %% [markdown]
# # Automated Road Damage Classification Using Deep Learning and Cloud Deployment
#
# ## 01 - Dataset Exploration
#
# ### Objective
# To understand the road damage image dataset, its folder structure,
# number of images, and damage categories before model training.

# %%
# Import the required libraries
# These libraries help us work with folders, images and data
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
